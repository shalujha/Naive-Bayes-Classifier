# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
gnb=GaussianNB()
print(gnb)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
X,Y=make_classification(n_samples=200,n_features=2,n_informative=2,n_redundant=0,random_state=5)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (200, 2)
# (200,)

# %%
plt.style.use('seaborn')
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
# train our classifier
gnb.fit(X,Y)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
gnb.score(X,Y)
# Out:
# 0.915

# %%
predictions=gnb.predict(X)

# %%
import numpy as np

# %%
accuracy=np.sum(Y==predictions)/(Y.shape[0])

# %%
print(accuracy)
# Out:
# 0.915

# %% [markdown]
# # Laplace Smoothing
# - laplace smoothing is a process which has been introduced to resolve the problem of estimation of unseen word from training set as 0 . In laplace smoothing , we
